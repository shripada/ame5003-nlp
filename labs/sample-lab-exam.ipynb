# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shripada/ame5003-nlp/blob/main/labs/sample-lab-exam.ipynb)
#
# **Click the badge above to open this lab in Google Colab.** Then choose *File → Save a copy in Drive* so your work is saved.

# %% [markdown]
# # Sample mid-semester lab examination
#
# **MSIS · AME 5053 · 90 minutes · 30 marks · Open book and internet**
#
# This sample examination covers Labs 1–5. Answer all three questions. Each question carries 10 marks.

# %% [markdown]
# ## Instructions
#
# 1. You may consult the course notes, the notebooks for Labs 1–5, and resources on the internet.
# 2. Write your answers only in the cells marked **Your answer**. You may add cells if required.
# 3. Run the notebook from top to bottom before submitting it. It must finish without an error.
# 4. Unless a question says otherwise, use only Python's standard library and the `regex` package used in the labs.
# 5. Brief written explanations are part of the marks where they are requested.
#
# Enter your details below, then run the setup cells.

# %%
name = ""
registration_number = ""

# %%
# The labs use this package for Unicode-safe regular expressions.
# %pip install -q regex

# %%
from collections import Counter, defaultdict
from fractions import Fraction
import unicodedata
import regex

print("Setup complete")

# %% [markdown]
# ---
#
# ## Question 1 — Extracting and normalising text (10 marks)
#
# The following messages came from three different order systems. Notice that the date separators differ and that the second message writes `Café` using a decomposed accent.

# %%
messages = [
    "Order ORD-1042: Café Mysuru charged ₹1,250.50 on 12/09/2026.",
    "order ord-1043 — CAFE\u0301 MYSURU charged ₹799 on 13-09-2026.",
    "Order ORD-1044: ಪುಸ್ತಕ ಅಂಗಡಿ charged ₹2,040.00 on 14/09/2026.",
]

for message in messages:
    print(message)

# %% [markdown]
# ### (a) Structured fields (5 marks)
#
# Write regular expressions that extract the order identifier, amount and date from each message. Your code must accept either `/` or `-` as the date separator and must match `Order` without depending on its case. Remove the comma from each amount and convert it to `float`. Store the results as a list of dictionaries with the keys `order_id`, `amount` and `date`, then print the list.
#
# Marks: correct order identifiers (1), amounts as numbers (2), both date separators (1), required list of dictionaries (1).

# %%
# Your answer to Question 1(a)
records = []

# Write your code here.

# %% [markdown]
# ### (b) One vocabulary (5 marks)
#
# Write a function `normalise_tokens(text)` that performs the following operations in this order:
#
# 1. applies NFC Unicode normalisation and case folding;
# 2. replaces every order identifier with the token `ORDER`, every amount with `AMOUNT`, and every date with `DATE`;
# 3. returns only word tokens. A word may contain Unicode letters or combining marks, so the Kannada words must remain intact.
#
# Apply the function to all three messages. Print the sorted vocabulary and its size. In two or three sentences, explain why Unicode normalisation must happen before we count a vocabulary.
#
# Marks: Unicode normalisation and case folding (1), replacements (1), Unicode-safe tokenisation (1), vocabulary and size (1), explanation (1).

# %%
# Your answer to Question 1(b)
def normalise_tokens(text):
    # Replace this line with your implementation.
    return []

# Build and print the vocabulary here.

# %% [markdown]
# **Explanation:** Write your answer here.

# %% [markdown]
# ---
#
# ## Question 2 — An inverted index and a Boolean query (10 marks)
#
# We will search the following six short documents. A document identifier is the integer on the left.

# %%
documents = {
    1: "Machine learning helps hospitals.",
    2: "Hospitals use language models for clinical notes.",
    3: "Machine translation uses language models.",
    4: "Clinical notes contain private data.",
    5: "Translation systems learn from parallel data.",
    6: "Hospitals protect private patient data.",
}

# %% [markdown]
# ### (a) Build the index (5 marks)
#
# Tokenise each document into lower-case alphabetic words, without punctuation. Build an inverted index whose keys are terms and whose values are sorted postings lists of document identifiers. Print the postings lists for `clinical`, `data` and `models`.
#
# Marks: correct tokenisation (2), complete index (2), sorted requested postings lists (1).

# %%
# Your answer to Question 2(a)
index = defaultdict(list)

# Build and inspect the index here.

# %% [markdown]
# ### (b) Process a Boolean query (5 marks)
#
# Implement `intersect(left, right)` with the two-pointer merge from Lab 4. Do not convert the postings lists to sets inside this function. Use it to answer:
#
# ```text
# language AND models AND NOT machine
# ```
#
# Print the matching document identifiers and their text. Then explain in one or two sentences why the query must undergo the same normalisation as the documents.
#
# Marks: correct two-pointer merge (3), correct query result (1), explanation (1).

# %%
# Your answer to Question 2(b)
def intersect(left, right):
    result = []
    # Complete the two-pointer merge.
    return result

# Evaluate the query and print the matching documents here.

# %% [markdown]
# **Explanation:** Write your answer here.

# %% [markdown]
# ---
#
# ## Question 3 — A bigram language model (10 marks)
#
# Train a bigram model on this corpus. Treat every sentence as beginning with `<s>` and ending with `</s>`. Keep all tokens lower-case.

# %%
corpus = [
    "students read books",
    "students read notes",
    "teachers read books",
    "students write notes",
]

# %% [markdown]
# ### (a) Counts and an unsmoothed probability (5 marks)
#
# Build `bigram_counts` and `context_counts` from the corpus. Write `bigram_probability(word, context)` for the maximum-likelihood estimate
#
# $$P(w_i \mid w_{i-1}) = \frac{C(w_{i-1}, w_i)}{C(w_{i-1})}.$$
#
# Use the function to compute the complete sentence probability of `students read books`, including both sentence boundaries. Print the individual factors and the final exact value as a `Fraction`.
#
# Marks: boundary tokens (1), correct counts (2), probability function (1), sentence probability (1).

# %%
# Your answer to Question 3(a)
bigram_counts = Counter()
context_counts = Counter()

# Build the counts here.

def bigram_probability(word, context):
    # Replace this line with the maximum-likelihood estimate.
    return Fraction(0, 1)

# Compute and print the sentence probability here.

# %% [markdown]
# ### (b) An unseen sentence and add-one smoothing (5 marks)
#
# The predicted vocabulary contains every ordinary word in the training corpus and `</s>`, but it does not contain `<s>`. Write `add_one_probability(word, context, vocabulary_size)` and use it to compute the probability of `teachers write books`, again including both boundaries. Print the vocabulary, its size, the individual factors and the final exact value as a `Fraction`.
#
# In two or three sentences, explain why the unsmoothed probability of this sentence is zero and what add-one smoothing changes.
#
# Marks: vocabulary and size (1), add-one formula (2), sentence probability (1), explanation (1).

# %%
# Your answer to Question 3(b)
vocabulary = set()

def add_one_probability(word, context, vocabulary_size):
    # Replace this line with the add-one estimate.
    return Fraction(0, 1)

# Compute and print the smoothed sentence probability here.

# %% [markdown]
# **Explanation:** Write your answer here.

# %% [markdown]
# ---
#
# ## Before you submit
#
# Restart the runtime and run all cells. Check that you have entered your name and registration number, that every requested result is printed, and that no cell ends with an error.
